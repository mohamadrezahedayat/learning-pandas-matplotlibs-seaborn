# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### load_dataset()

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
penguins = sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# ## seaborn scatterpolts

# %%
sns.set_theme()

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
tips.plot(kind='scatter',x='total_bill',y='tip')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='smoker')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='sex')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='day')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='sex', style='time')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip', size='size',hue='sex')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### lineplot()

# %%
flights = sns.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.lineplot(data=flights, x = 'year', y='passengers', hue='month')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(data=flights, x = 'year', y='passengers')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(data=flights, x = 'year', y='passengers', estimator='sum')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
flights.groupby('year')['passengers'].mean().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
trips = sns.load_dataset('taxis', parse_dates=['pickup', 'dropoff'])
trips
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
trips['hour']= trips['pickup'].dt.hour

# %%
trips
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
sns.lineplot(data=trips, x='hour', y='total')
# Out:
# <AxesSubplot:xlabel='hour', ylabel='total'>

# %%
sns.lineplot(data=trips, x='hour', y='total',hue='payment')
# Out:
# <AxesSubplot:xlabel='hour', ylabel='total'>

# %%
sns.lineplot(data=trips, x='hour', y='total',hue='payment',style='color')
# Out:
# <AxesSubplot:xlabel='hour', ylabel='total'>

# %%
sns.lineplot(data=trips, x='hour', y='total',hue='payment',style='color',ci=None)
# Out:
# <AxesSubplot:xlabel='hour', ylabel='total'>

# %% [markdown]
# ### relplot()

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=tips, x='total_bill', y='tip')

# %%
sns.relplot(data=tips, x='total_bill', y='tip',col='sex')

# %%
sns.relplot(data=tips,kind='line', x='total_bill', y='tip',col='sex')

# %%
sns.relplot(data=tips, x='total_bill', y='tip',col='sex',hue='smoker')

# %%
sns.relplot(data=tips, x='total_bill', y='tip',
            col='sex', hue='smoker', row='time')

# %%
sns.relplot(data=trips, x='hour', y='total', kind='line',
            col='pickup_borough', row='dropoff_borough', hue='payment')

# %% [markdown]
# ### resizing seaborn plot aspects & heights

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=flights, x='year', y='passengers', hue='month')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.relplot(
    data=tips,
    x="total_bill",
    y="tip",
    col="sex",
    hue="smoker",
    row="time",
    height=3,
    aspect=2, #default is 1
)

# %% [markdown]
# ### histograms

# %%
sns.histplot(data=tips, x="tip")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=tips, x="tip", hue="time")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=tips, x="tip", hue="smoker")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=tips, x="tip", hue="smoker", multiple="stack")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=tips, x="tip", hue="smoker", multiple="dodge")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=penguins, x="body_mass_g", bins=30)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=penguins, x="body_mass_g", binwidth=100)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=penguins, x="body_mass_g", bins=30, hue="species")
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=penguins, x="body_mass_g", bins=30, hue="species",multiple='stack')
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(
    data=penguins,
    x="body_mass_g",
    bins=30,
    hue="species",
    multiple="stack",
    element="step",
)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=tips, x="tip", kde=True)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.histplot(
    data=penguins, x="body_mass_g", bins=30, hue="species", multiple="stack", kde=True
)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Count'>

# %% [markdown]
# ### KDE Plots

# %%
sns.kdeplot(data=penguins, x="body_mass_g", hue="species", multiple="stack")
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Density'>

# %%
sns.kdeplot(data=penguins, x="body_mass_g", hue="species")
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Density'>

# %%
sns.kdeplot(data=penguins, x="body_mass_g", hue="species", bw_adjust=0.4)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Density'>

# %% [markdown]
# ### Bivariate Distribution Plots

# %%
sns.histplot(data=penguins, x="flipper_length_mm")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins, x="body_mass_g")
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=penguins, x="body_mass_g", y='flipper_length_mm')
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.kdeplot(data=penguins, x="body_mass_g", y='flipper_length_mm')
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.kdeplot(data=penguins, x="bill_length_mm", y='flipper_length_mm',hue='species')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
sns.histplot(data=penguins, x="bill_length_mm", y='flipper_length_mm',hue='species',bins=20)
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %% [markdown]
# ### Rugplot

# %%
sns.rugplot(data=tips, x="tip", height=0.2)
# Out:
# <AxesSubplot:xlabel='tip'>

# %%
sns.rugplot(data=tips, y="tip", height=0.2)
# Out:
# <AxesSubplot:ylabel='tip'>

# %%
sns.kdeplot(data=tips, x='total_bill')
sns.rugplot(data=tips, x="total_bill", height=0.1)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.scatterplot(data=tips, x='total_bill',y='tip')
sns.rugplot(data=tips, x="total_bill", height=0.05)
sns.rugplot(data=tips, y="tip", height=0.05)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### displot

# %%
sns.displot(kind="hist", data=penguins, x="body_mass_g", height=3, aspect=2)

# %%
sns.displot(
    kind="hist", data=penguins, x="body_mass_g", hue="sex", col="species", 
)

# %%
sns.displot(
    kind="kde", data=tips, x="tip", col='time',rug=True
)

# %%
sns.displot(kind="kde", data=tips, x="total_bill", y="tip", col="time", rug=True)

# %% [markdown]
# ### countplot()

# %%
sns.countplot(data=penguins, x="species")
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
penguins.species.value_counts().plot(kind='bar',color=['blue','orange','green'])
# Out:
# <AxesSubplot:>

# %%
sns.countplot(data=penguins, x="species", hue="sex")
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
titanic = pd.read_csv('dataAnalysis/data/titanic.csv')

# %%
sns.countplot(data=titanic, x='pclass',hue='sex')
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %%
sns.countplot(data=titanic, y='pclass',hue='sex')
# Out:
# <AxesSubplot:xlabel='count', ylabel='pclass'>

# %% [markdown]
# ### strip & swarm plots

# %%
sns.scatterplot(data=trips,x='pickup_borough',y='distance')
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='distance'>

# %%
sns.stripplot(data=trips,x='pickup_borough',y='distance')
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='distance'>

# %%
trips_sample = trips.nlargest(800,'total')
plt.figure(figsize=(15,5))
sns.swarmplot(data=trips_sample,x='pickup_borough',y='distance')
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='distance'>

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.stripplot(data=titanic,x='pclass',y='age',hue='sex')
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
plt.figure(figsize=(15,5))
sns.swarmplot(data=titanic,x='pclass',y='age',hue='sex')
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %% [markdown]
# ### boxplot

# %%
sns.boxplot(data=titanic, x='age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.boxplot(data=trips, x='pickup_borough', y='total')
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='total'>

# %%
sns.boxplot(data=titanic,x='pclass',y='age')
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(data=titanic,x='pclass',y='age', hue='sex',fliersize=2)
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(data=penguins, x="species", y="body_mass_g")
sns.swarmplot(data=penguins, x="species", y="body_mass_g", color="black")
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# ### boxen plot

# %%
sns.boxenplot(data=trips, x='pickup_borough',y='total')
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='total'>

# %%
sns.boxplot(data=trips, x='pickup_borough',y='total')
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='total'>

# %% [markdown]
# ### violinplot

# %%
sns.violinplot(data=trips, x='pickup_borough',y='total')
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='total'>

# %%
sns.violinplot(data=titanic,x='pclass',y='age')
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(data=titanic,x='pclass',y='age')
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %% [markdown]
# ### barplot

# %%
sns.barplot(data=trips,x='pickup_borough',y='total')
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='total'>

# %%
sns.barplot(data=trips,x='pickup_borough',y='total',estimator=sum)
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='total'>

# %%
sns.barplot(data=trips, x="pickup_borough", y="total", estimator=sum, hue="color")
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='total'>

# %% [markdown]
# ### catplot

# %%
sns.catplot(data=titanic, kind="bar", y="survived", x="sex", col="pclass")

# %%
sns.catplot(data=trips, kind="strip", x="pickup_borough", y="distance", col="color")

# %%
sns.catplot(
    data=trips, kind="violin", x="pickup_borough", y="distance", hue="color", split=True
)

# %%
sns.catplot(
    data=trips,
    kind="violin",
    x="pickup_borough",
    y="distance",
    hue="color",
    split=True,
    aspect=2,
)

# %%
sns.catplot(
    data=titanic,
    kind="bar",
    x="who",
    y="survived",
    col="pclass",
    row="embarked",
    ci=None,
)
