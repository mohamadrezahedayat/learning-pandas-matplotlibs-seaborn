# %% [markdown]
# ## upper lower and capitalize

# %%
import pandas as pd
titanic = pd.read_csv("DataAnalysis/data/titanic.csv")

# %%
titanic['name']
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
titanic['name'].str.lower()
# Out:
# 0                         allen, miss. elisabeth walton
# 1                        allison, master. hudson trevor
# 2                          allison, miss. helen loraine
# 3                  allison, mr. hudson joshua creighton
# 4       allison, mrs. hudson j c (bessie waldo daniels)
#                              ...
# 1304                               zabour, miss. hileni
# 1305                              zabour, miss. thamine
# 1306                          zakarian, mr. mapriededer
# 1307                                zakarian, mr. ortin
# 1308                                 zimmerman, mr. leo
# Name: name, Length: 1309, dtype: object

# %%
titanic['name'].str.upper()
# Out:
# 0                         ALLEN, MISS. ELISABETH WALTON
# 1                        ALLISON, MASTER. HUDSON TREVOR
# 2                          ALLISON, MISS. HELEN LORAINE
# 3                  ALLISON, MR. HUDSON JOSHUA CREIGHTON
# 4       ALLISON, MRS. HUDSON J C (BESSIE WALDO DANIELS)
#                              ...
# 1304                               ZABOUR, MISS. HILENI
# 1305                              ZABOUR, MISS. THAMINE
# 1306                          ZAKARIAN, MR. MAPRIEDEDER
# 1307                                ZAKARIAN, MR. ORTIN
# 1308                                 ZIMMERMAN, MR. LEO
# Name: name, Length: 1309, dtype: object

# %%
titanic['name'].str.capitalize()
# Out:
# 0                         Allen, miss. elisabeth walton
# 1                        Allison, master. hudson trevor
# 2                          Allison, miss. helen loraine
# 3                  Allison, mr. hudson joshua creighton
# 4       Allison, mrs. hudson j c (bessie waldo daniels)
#                              ...
# 1304                               Zabour, miss. hileni
# 1305                              Zabour, miss. thamine
# 1306                          Zakarian, mr. mapriededer
# 1307                                Zakarian, mr. ortin
# 1308                                 Zimmerman, mr. leo
# Name: name, Length: 1309, dtype: object

# %% [markdown]
# ### indexing string series with []

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.cabin
# Out:
# 0            B5
# 1       C22 C26
# 2       C22 C26
# 3       C22 C26
# 4       C22 C26
#          ...
# 1304          ?
# 1305          ?
# 1306          ?
# 1307          ?
# 1308          ?
# Name: cabin, Length: 1309, dtype: object

# %%
titanic.cabin.str[0]
# Out:
# 0       B
# 1       C
# 2       C
# 3       C
# 4       C
#        ..
# 1304    ?
# 1305    ?
# 1306    ?
# 1307    ?
# 1308    ?
# Name: cabin, Length: 1309, dtype: object

# %%
titanic.cabin.str[0].value_counts()
# Out:
# ?    1014
# C      94
# B      65
# D      46
# E      41
# A      22
# F      21
# G       5
# T       1
# Name: cabin, dtype: int64

# %%
titanic.cabin.str[0].value_counts().sort_index().tail(8).plot()
# Out:
# <AxesSubplot:>

# %%
titanic['deck']=titanic.cabin.str[0]
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.groupby('deck').mean()
# Out:
#         pclass  survived     sibsp     parch
# deck
# ?     2.617357  0.302761  0.503945  0.367850
# A     1.000000  0.500000  0.181818  0.181818
# B     1.000000  0.723077  0.446154  0.661538
# C     1.000000  0.606383  0.680851  0.414894
# D     1.130435  0.695652  0.413043  0.260870
# E     1.243902  0.731707  0.341463  0.390244
# F     2.380952  0.619048  0.428571  0.523810
# G     3.000000  0.600000  0.600000  1.200000
# T     1.000000  0.000000  0.000000  0.000000

# %% [markdown]
# ### stripping whitespace with strip()

# %%
s = pd.Series(['1. Hawk.  ', '2. Pickle!\n', '3. Melonhead?\t'])

# %%
s
# Out:
# 0         1. Hawk.
# 1       2. Pickle!\n
# 2    3. Melonhead?\t
# dtype: object

# %%
s.str.strip()
# Out:
# 0         1. Hawk.
# 1       2. Pickle!
# 2    3. Melonhead?
# dtype: object

# %%
s.str.strip(to_strip="123. \n\t")
# Out:
# 0          Hawk
# 1       Pickle!
# 2    Melonhead?
# dtype: object

# %%
s.str.rstrip()
# Out:
# 0         1. Hawk.
# 1       2. Pickle!
# 2    3. Melonhead?
# dtype: object

# %%
s.str.lstrip()
# Out:
# 0         1. Hawk.
# 1       2. Pickle!\n
# 2    3. Melonhead?\t
# dtype: object

# %% [markdown]
# ### splitting text values with split()

# %%
titanic['home.dest'].str.split('/')
# Out:
# 0                           [St Louis, MO]
# 1       [Montreal, PQ ,  Chesterville, ON]
# 2       [Montreal, PQ ,  Chesterville, ON]
# 3       [Montreal, PQ ,  Chesterville, ON]
# 4       [Montreal, PQ ,  Chesterville, ON]
#                        ...
# 1304                                   [?]
# 1305                                   [?]
# 1306                                   [?]
# 1307                                   [?]
# 1308                                   [?]
# Name: home.dest, Length: 1309, dtype: object

# %%
titanic['home.dest'].str.split('/',expand=True)
# Out:
#                   0                  1     2
# 0      St Louis, MO               None  None
# 1     Montreal, PQ    Chesterville, ON  None
# 2     Montreal, PQ    Chesterville, ON  None
# 3     Montreal, PQ    Chesterville, ON  None
# 4     Montreal, PQ    Chesterville, ON  None
# ...             ...                ...   ...
# 1304              ?               None  None
# 1305              ?               None  None
# 1306              ?               None  None
# 1307              ?               None  None
# 1308              ?               None  None
#
# [1309 rows x 3 columns]

# %%
titanic['home'] = titanic['home.dest'].str.split('/',expand=True)[0]

# %%
titanic['destination'] = titanic['home.dest'].str.split('/',expand=True)[1]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic['home.dest'].str.split('/',expand=True,n=1)
# Out:
#                   0                  1
# 0      St Louis, MO               None
# 1     Montreal, PQ    Chesterville, ON
# 2     Montreal, PQ    Chesterville, ON
# 3     Montreal, PQ    Chesterville, ON
# 4     Montreal, PQ    Chesterville, ON
# ...             ...                ...
# 1304              ?               None
# 1305              ?               None
# 1306              ?               None
# 1307              ?               None
# 1308              ?               None
#
# [1309 rows x 2 columns]

# %% [markdown]
# ### replacing a portion of string

# %%
titanic.cabin.str.replace('?','Unknown')
# Out:
# C:\Users\hedi\AppData\Local\Temp\ipykernel_25468\3996860678.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   titanic.cabin.str.replace('?','Unknown')
# 0            B5
# 1       C22 C26
# 2       C22 C26
# 3       C22 C26
# 4       C22 C26
#          ...
# 1304    Unknown
# 1305    Unknown
# 1306    Unknown
# 1307    Unknown
# 1308    Unknown
# Name: cabin, Length: 1309, dtype: object

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# ### contain()

# %%
titanic.name.str.contains('Mr')
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 1304    False
# 1305    False
# 1306     True
# 1307     True
# 1308     True
# Name: name, Length: 1309, dtype: bool

# %%
titanic.name.str.contains('Mr',na=False)
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 1304    False
# 1305    False
# 1306     True
# 1307     True
# 1308     True
# Name: name, Length: 1309, dtype: bool
