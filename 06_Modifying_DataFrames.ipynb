# %%
import pandas as pd
houses = pd.read_csv("DataAnalysis/data/kc_house_data.csv")
titanic = pd.read_csv("DataAnalysis/data/titanic.csv")
btc = pd.read_csv("DataAnalysis/data/coin_Bitcoin.csv")
netflix=pd.read_csv("DataAnalysis/data/netflix_titles.csv",sep='|',index_col=0)
countries = pd.read_csv("DataAnalysis/data/world-happiness-report-2021.csv")

# %%
countries.set_index('Country name',inplace=True)

# %%
btc
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %% [markdown]
# ## dropping columns

# %%
btc.drop(labels='Symbol', axis=1)
# Out:
#        SNo     Name                 Date          High           Low  \
# 0        1  Bitcoin  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...                  ...           ...           ...
# 2986  2987  Bitcoin  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin  2021-07-06 23:59:59  35038.536363  33599.916169
#
#               Open         Close        Volume     Marketcap
# 0       134.444000    144.539993  0.000000e+00  1.603769e+09
# ...

# %%
btc.drop(labels=['SNo','Name','Symbol'], axis='columns')
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# 0       144.539993  0.000000e+00  1.603769e+09
# 1       139.000000  0.000000e+00  1.542813e+09
# ...

# %%
btc.drop(columns=['SNo','Name','Symbol'],inplace=True)

# %%
btc
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# 0       144.539993  0.000000e+00  1.603769e+09
# 1       139.000000  0.000000e+00  1.542813e+09
# ...

# %% [markdown]
# ## dropping rows

# %%
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
countries.drop(labels='Denmark',axis=0)
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# ...

# %%
countries.drop(labels='Finland')
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# ...

# %%
countries.drop(labels=['Denmark','Finland','Iceland'])
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Switzerland       Western Europe         7.571
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# Sweden            Western Europe         7.363
# Luxembourg        Western Europe         7.324
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Switzerland                            0.036         7.643         7.500
# Netherlands                            0.027         7.518         7.410
# Norway                                 0.035         7.462         7.323
# ...

# %%
btc.sort_index(ascending=False,inplace=True)

# %%
btc.drop(2990)
# Out:
#                      Date          High           Low          Open  \
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2985  2021-07-01 23:59:59  35035.982712  32883.781226  35035.982712
# ...                   ...           ...           ...           ...
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
#
#              Close        Volume     Marketcap
# 2989  33746.002456  2.672155e+10  6.326962e+11
# 2988  35287.779766  2.492431e+10  6.615748e+11
# ...

# %%
countries.drop(countries.index[0:3])
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# Sweden            Western Europe         7.363
# Luxembourg        Western Europe         7.324
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Iceland                                0.059         7.670         7.438
# Netherlands                            0.027         7.518         7.410
# Norway                                 0.035         7.462         7.323
# ...

# %%
countries.drop(countries.index[10:])
# Out:
#                  Regional indicator  Ladder score  \
# Country name
# Finland              Western Europe         7.842
# Denmark              Western Europe         7.620
# Switzerland          Western Europe         7.571
# Iceland              Western Europe         7.554
# Netherlands          Western Europe         7.464
# Norway               Western Europe         7.392
# Sweden               Western Europe         7.363
# Luxembourg           Western Europe         7.324
# New Zealand   North America and ANZ         7.277
# Austria              Western Europe         7.268
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# ...

# %% [markdown]
# ## adding static columns

# %%
titanic['species'] = 'human'

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# ### insert

# %%
houses.insert(0,'country','King Country')

# %%
houses
# Out:
#             country          id             date     price  bedrooms  \
# 0      King Country  7129300520  20141013T000000  221900.0         3
# 1      King Country  6414100192  20141209T000000  538000.0         3
# 2      King Country  5631500400  20150225T000000  180000.0         2
# 3      King Country  2487200875  20141209T000000  604000.0         4
# 4      King Country  1954400510  20150218T000000  510000.0         3
# ...             ...         ...              ...       ...       ...
# 21608  King Country   263000018  20140521T000000  360000.0         3
# 21609  King Country  6600060120  20150223T000000  400000.0         4
# 21610  King Country  1523300141  20140623T000000  402101.0         2
# 21611  King Country   291310100  20150116T000000  400000.0         3
# 21612  King Country  1523300157  20141015T000000  325000.0         2
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  grade  \
# ...

# %% [markdown]
# ## creating new dynamic columns

# %%
houses.insert(1,'price/bedrooms',houses.price/(houses.bedrooms+1))

# %%
houses.sort_values('price/bedrooms').head(50)
# Out:
#             country  price/bedrooms          id             date     price  \
# 15870  King Country    18823.529412  2402100895  20140625T000000  640000.0
# 5639   King Country    20000.000000  7224000980  20140610T000000  100000.0
# 8274   King Country    20500.000000  3883800011  20141105T000000   82000.0
# 13756  King Country    21625.000000  1788900230  20140722T000000   86500.0
# 15810  King Country    22166.666667  7129304540  20141220T000000  133000.0
# 5866   King Country    22250.000000  9320900420  20141014T000000   89000.0
# 18939  King Country    22500.000000  4239400300  20141129T000000   90000.0
# 5723   King Country    24125.000000  1788800630  20141029T000000   96500.0
# 3540   King Country    25000.000000  1823049202  20140610T000000  175000.0
# 12338  King Country    25000.000000  5132000140  20140618T000000  175000.0
# 15293  King Country    26000.000000    40000362  20140506T000000   78000.0
# ...

# %%
btc.set_index('Date')
btc['change']=abs( btc.Close-btc.Open)

# %%
btc.sort_values('change',ascending=False)
# Out:
#                      Date          High           Low          Open  \
# 2935  2021-05-12 23:59:59  57939.362415  49150.533875  56714.533167
# 2842  2021-02-08 23:59:59  46203.931437  38076.322807  38886.827290
# 2942  2021-05-19 23:59:59  43546.116485  30681.496912  42944.975447
# 2857  2021-02-23 23:59:59  54204.929756  45290.590268  54204.929756
# 2919  2021-04-26 23:59:59  54288.002155  48852.796843  49077.792363
# ...                   ...           ...           ...           ...
# 757   2015-05-26 23:59:59    238.242004    235.692001    237.104004
# 47    2013-06-15 23:59:59    103.699997     98.000000    100.000000
# 933   2015-11-18 23:59:59    336.531006    330.640015    334.592987
# 19    2013-05-18 23:59:59    125.250000    122.300003    123.500000
# 100   2013-08-07 23:59:59    106.750000    106.750000    106.750000
#
#              Close        Volume     Marketcap       change
# 2935  49150.533875  7.521540e+10  9.195278e+11  7563.999292
# ...

# %% [markdown]
# ### renaming columns

# %%
countries.head(2)
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Finland          Western Europe         7.842                           0.032
# Denmark          Western Europe         7.620                           0.035
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Finland              7.904         7.780                 10.775
# Denmark              7.687         7.552                 10.933
#
#               Social support  Healthy life expectancy  \
# Country name
# Finland                0.954                     72.0
# Denmark                0.954                     72.7
#
#               Freedom to make life choices  Generosity  \
# Country name
# Finland                              0.949      -0.098
# Denmark                              0.946       0.030
#
#               Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# ...

# %%
mapper={'Regional indicator':'regional_indicator','Ladder score':'ladder_score'}
countries.rename(columns=mapper,inplace=True)

# %%
countries
# Out:
#               regional_indicator  ladder_score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %% [markdown]
# #### renaming index label

# %%
mapper={'Finland':'finland','Denmark':'denmark'}
countries.rename(index=mapper)
# Out:
#               regional_indicator  ladder_score  \
# Country name
# finland           Western Europe         7.842
# denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# finland                                0.032         7.904         7.780
# denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %% [markdown]
# ### update()

# %%
titanic['sex'].replace('female','f')
# Out:
# 0          f
# 1       male
# 2          f
# 3       male
# 4          f
#         ...
# 1304       f
# 1305       f
# 1306    male
# 1307    male
# 1308    male
# Name: sex, Length: 1309, dtype: object

# %%
titanic['sex'].replace(['f','m'],['F','M'],inplace=True)

# %%
titanic
# Out:
#       pclass  survived                                             name sex  \
# 0          1         1                    Allen, Miss. Elisabeth Walton   F
# 1          1         1                   Allison, Master. Hudson Trevor   M
# 2          1         0                     Allison, Miss. Helen Loraine   F
# 3          1         0             Allison, Mr. Hudson Joshua Creighton   M
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)   F
# ...      ...       ...                                              ...  ..
# 1304       3         0                             Zabour, Miss. Hileni   F
# 1305       3         0                            Zabour, Miss. Thamine   F
# 1306       3         0                        Zakarian, Mr. Mapriededer   M
# 1307       3         0                              Zakarian, Mr. Ortin   M
# 1308       3         0                               Zimmerman, Mr. Leo   M
#
# ...

# %% [markdown]
# #### replacing ? with None

# %%
titanic['age'].replace(['?'],[None],inplace=True)

# %%
titanic.age.value_counts(dropna=False)
# Out:
# None      263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 66          1
# 0.6667      1
# 76          1
# 67          1
# 26.5        1
# Name: age, Length: 99, dtype: int64

# %% [markdown]
# ### updating value using loc[]

# %%
countries.loc['Brazil']
# Out:
# regional_indicator                            Latin America and Caribbean
# ladder_score                                                         6.33
# Standard error of ladder score                                      0.043
# upperwhisker                                                        6.415
# lowerwhisker                                                        6.245
# Logged GDP per capita                                               9.577
# Social support                                                      0.882
# Healthy life expectancy                                            66.601
# Freedom to make life choices                                        0.804
# Generosity                                                         -0.071
# Perceptions of corruption                                           0.756
# Ladder score in Dystopia                                             2.43
# Explained by: Log GDP per capita                                    1.028
# ...

# %%
countries.loc['Brazil':"Iran"]
# Out:
#                         regional_indicator  ladder_score  \
# Country name
# Brazil         Latin America and Caribbean         6.330
# Mexico         Latin America and Caribbean         6.317
# Jamaica        Latin America and Caribbean         6.309
# Lithuania       Central and Eastern Europe         6.255
# Cyprus                      Western Europe         6.223
# ...                                    ...           ...
# Cambodia                    Southeast Asia         4.830
# Mozambique              Sub-Saharan Africa         4.794
# Nigeria                 Sub-Saharan Africa         4.759
# Mali                    Sub-Saharan Africa         4.723
# Iran          Middle East and North Africa         4.721
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Brazil                                 0.043         6.415         6.245
# Mexico                                 0.053         6.420         6.213
# ...

# %%
countries.loc['Iran',['ladder_score']]
# Out:
# ladder_score    4.721
# Name: Iran, dtype: object

# %%
countries.loc['Iran',['ladder_score','Generosity','Healthy life expectancy']]
# Out:
# ladder_score               4.721
# Generosity                 0.218
# Healthy life expectancy     66.3
# Name: Iran, dtype: object

# %%
countries.loc[['Iran','Iraq','Pakistan','India',"Turkey"],['ladder_score','Generosity','Healthy life expectancy']]
# Out:
#               ladder_score  Generosity  Healthy life expectancy
# Country name
# Iran                 4.721       0.218                   66.300
# Iraq                 4.854      -0.053                   60.583
# Pakistan             4.934       0.098                   58.709
# India                3.819       0.089                   60.633
# Turkey               4.948      -0.139                   67.199

# %%
countries.loc[['Denmark','Sweden','Norway'],['regional_indicator']]='Scandinavia'

# %%
countries.loc[['Denmark','Sweden','Norway'],['regional_indicator']]
# Out:
#              regional_indicator
# Country name
# Denmark             Scandinavia
# Sweden              Scandinavia
# Norway              Scandinavia

# %%
countries.loc['Finland']='LOL'

# %%
countries.loc[['Finland'],['upperwhisker','lowerwhisker']]='Meaow'
countries
# Out:
#               regional_indicator ladder_score Standard error of ladder score  \
# Country name
# Finland                      LOL          LOL                            LOL
# Denmark              Scandinavia         7.62                          0.035
# Switzerland       Western Europe        7.571                          0.036
# Iceland           Western Europe        7.554                          0.059
# Netherlands       Western Europe        7.464                          0.027
# ...                          ...          ...                            ...
# Lesotho       Sub-Saharan Africa        3.512                           0.12
# Botswana      Sub-Saharan Africa        3.467                          0.074
# Rwanda        Sub-Saharan Africa        3.415                          0.068
# Zimbabwe      Sub-Saharan Africa        3.145                          0.058
# Afghanistan           South Asia        2.523                          0.038
#
# ...

# %%
### updating multiple values using loc

# %%
countries.loc[['Finland','Denmark','Iceland','Sweden','Norway']]
# Out:
#              regional_indicator ladder_score Standard error of ladder score  \
# Country name
# Finland                     LOL          LOL                            LOL
# Denmark             Scandinavia         7.62                          0.035
# Iceland          Western Europe        7.554                          0.059
# Sweden              Scandinavia        7.363                          0.036
# Norway              Scandinavia        7.392                          0.035
#
#              upperwhisker lowerwhisker Logged GDP per capita Social support  \
# Country name
# Finland             Meaow        Meaow                   LOL            LOL
# Denmark             7.687        7.552                10.933          0.954
# Iceland              7.67        7.438                10.878          0.983
# Sweden              7.433        7.293                10.867          0.934
# Norway              7.462        7.323                11.053          0.954
#
# ...

# %%
countries.loc[['Finland','Denmark','Iceland','Sweden','Norway'],['regional_indicator','climate']]='Dogs'

# %%
countries.loc[['Finland','Denmark','Iceland','Sweden','Norway'],['regional_indicator','climate']]
# Out:
#              regional_indicator climate
# Country name
# Finland                    Dogs    Dogs
# Denmark                    Dogs    Dogs
# Iceland                    Dogs    Dogs
# Sweden                     Dogs    Dogs
# Norway                     Dogs    Dogs

# %%
countries.loc[['Finland','Denmark','Iceland','Sweden','Norway'],['regional_indicator','climate']]=['Scandinavia','Cold']

# %%
countries.loc[['Finland','Denmark','Iceland','Sweden','Norway'],['regional_indicator','climate']]
# Out:
#              regional_indicator climate
# Country name
# Finland             Scandinavia    Cold
# Denmark             Scandinavia    Cold
# Iceland             Scandinavia    Cold
# Sweden              Scandinavia    Cold
# Norway              Scandinavia    Cold

# %%
countries
# Out:
#               regional_indicator ladder_score Standard error of ladder score  \
# Country name
# Finland              Scandinavia          LOL                            LOL
# Denmark              Scandinavia         7.62                          0.035
# Switzerland       Western Europe        7.571                          0.036
# Iceland              Scandinavia        7.554                          0.059
# Netherlands       Western Europe        7.464                          0.027
# ...                          ...          ...                            ...
# Lesotho       Sub-Saharan Africa        3.512                           0.12
# Botswana      Sub-Saharan Africa        3.467                          0.074
# Rwanda        Sub-Saharan Africa        3.415                          0.068
# Zimbabwe      Sub-Saharan Africa        3.145                          0.058
# Afghanistan           South Asia        2.523                          0.038
#
# ...

# %% [markdown]
# ### making update with loc[] and boolean masks

# %%
many_bedrooms = houses['bedrooms'] >= 10
many_bedrooms
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Name: bedrooms, Length: 21613, dtype: bool

# %%
# houses[many_bedrooms]
houses.loc[many_bedrooms]
# Out:
#             country  price/bedrooms          id             date      price  \
# 8757   King Country    43333.333333  1773100755  20140821T000000   520000.0
# 13314  King Country   104363.636364   627300145  20140814T000000  1148000.0
# 15161  King Country    59090.909091  5566100170  20141029T000000   650000.0
# 15870  King Country    18823.529412  2402100895  20140625T000000   640000.0
# 19254  King Country    60000.000000  8812401450  20141229T000000   660000.0
#
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  grade  \
# 8757         11       3.00         3000      4960     2.0  ...      7
# 13314        10       5.25         4590     10920     1.0  ...      9
# 15161        10       2.00         3610     11914     2.0  ...      7
# 15870        33       1.75         1620      6000     1.0  ...      7
# 19254        10       3.00         2920      3745     2.0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# ...

# %%
houses.loc[many_bedrooms,['bedrooms','bathrooms']]
# houses[many_bedrooms,['bedrooms','bathrooms']]    it will throw error
# Out:
#        bedrooms  bathrooms
# 8757         11       3.00
# 13314        10       5.25
# 15161        10       2.00
# 15870        33       1.75
# 19254        10       3.00

# %%
houses.loc[many_bedrooms,['bedrooms']]='to many!'

# %%
houses.loc[many_bedrooms,['bedrooms']]
# Out:
#        bedrooms
# 8757   to many!
# 13314  to many!
# 15161  to many!
# 15870  to many!
# 19254  to many!

# %%
high_quality = houses['grade'] > 12
great_view = houses['view'] == 4
houses[high_quality & great_view]
# Out:
#             country  price/bedrooms          id             date      price  \
# 9254   King Country   983571.428571  9208900037  20140919T000000  6885000.0
# 14556  King Country   481333.333333  2303900035  20140611T000000  2888000.0
# 19017  King Country   950000.000000  2303900100  20140911T000000  3800000.0
#
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  grade  \
# 9254         6       7.75         9890     31374     2.0  ...     13
# 14556        5       6.25         8670     64033     2.0  ...     13
# 19017        3       4.25         5510     35000     2.0  ...     13
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 9254         8860           1030      2001             0    98039  47.6305
# 14556        6120           2550      1965          2003    98177  47.7295
# 19017        4910            600      1997             0    98177  47.7296
#
#           long  sqft_living15  sqft_lot15
# ...

# %%
houses['luxury_level']='normal'
houses
# Out:
#             country  price/bedrooms          id             date     price  \
# 0      King Country    55475.000000  7129300520  20141013T000000  221900.0
# 1      King Country   134500.000000  6414100192  20141209T000000  538000.0
# 2      King Country    60000.000000  5631500400  20150225T000000  180000.0
# 3      King Country   120800.000000  2487200875  20141209T000000  604000.0
# 4      King Country   127500.000000  1954400510  20150218T000000  510000.0
# ...             ...             ...         ...              ...       ...
# 21608  King Country    90000.000000   263000018  20140521T000000  360000.0
# 21609  King Country    80000.000000  6600060120  20150223T000000  400000.0
# 21610  King Country   134033.666667  1523300141  20140623T000000  402101.0
# 21611  King Country   100000.000000   291310100  20150116T000000  400000.0
# 21612  King Country   108333.333333  1523300157  20141015T000000  325000.0
#
# ...

# %%
houses.loc[high_quality & great_view,['luxury_level']]='ultra luxury'
houses[high_quality & great_view]
# Out:
#             country  price/bedrooms          id             date      price  \
# 9254   King Country   983571.428571  9208900037  20140919T000000  6885000.0
# 14556  King Country   481333.333333  2303900035  20140611T000000  2888000.0
# 19017  King Country   950000.000000  2303900100  20140911T000000  3800000.0
#
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  sqft_above  \
# 9254         6       7.75         9890     31374     2.0  ...        8860
# 14556        5       6.25         8670     64033     2.0  ...        6120
# 19017        3       4.25         5510     35000     2.0  ...        4910
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 9254            1030      2001             0    98039  47.6305 -122.240
# 14556           2550      1965          2003    98177  47.7295 -122.372
# 19017            600      1997             0    98177  47.7296 -122.370
#
#        sqft_living15  sqft_lot15  luxury_level
# ...

# %%
houses.luxury_level.value_counts()
# Out:
# normal          21610
# ultra luxury        3
# Name: luxury_level, dtype: int64
