# %%
import pandas as pd
# Out:
# '2019-12-31'

# %%
"2019-12-31"
"2019/12/31"
"December 31st 2019"
"December 31st 2019 4pm"
"December 31st 2019 4:59am"
"Dec. 25 1990 12pm"
"3:55:45 Apr. 2nd 90"

# %% [markdown]
# ### converting with pd.to_datetime()

# %%
pd.to_datetime("2019-12-31")
# Out:
# Timestamp('2019-12-31 00:00:00')

# %%
pd.to_datetime("2019/12/31")
# Out:
# Timestamp('2019-12-31 00:00:00')

# %%
pd.to_datetime("December 31st 2019")
# Out:
# Timestamp('2019-12-31 00:00:00')

# %%
pd.to_datetime("December 31st 2019 4pm")
# Out:
# Timestamp('2019-12-31 16:00:00')

# %%
pd.to_datetime("December 31st 2019 4:59am")
# Out:
# Timestamp('2019-12-31 04:59:00')

# %%
pd.to_datetime("Dec. 25 1990 12pm")
# Out:
# Timestamp('1990-12-25 12:00:00')

# %%
pd.to_datetime("3:55:45 Apr. 2nd 90")
# Out:
# Timestamp('1990-04-02 03:55:45')

# %% [markdown]
# #### specify fancy formats with pd.to_datetime()

# %%
pd.to_datetime('10/11/12') # it is ambigues
# Out:
# Timestamp('2012-10-11 00:00:00')

# %%
pd.to_datetime('10/11/12',dayfirst=True)
# Out:
# Timestamp('2012-11-10 00:00:00')

# %%
pd.to_datetime('10/11/12',yearfirst=True)
# Out:
# Timestamp('2010-11-12 00:00:00')

# %%
pd.to_datetime('10/11/12',yearfirst=True,dayfirst=True)
# Out:
# Timestamp('2010-12-11 00:00:00')

# %% [markdown]
# ### format()

# %%
pd.to_datetime('10/11/12',format='%y/%m/%d')
# Out:
# Timestamp('2010-11-12 00:00:00')

# %%
meetings = ['Dec 11 2019 Meeting', 'Jan 6 2020 Meeting', 'Mar 19 2020 Meeting','Apr 15 2020 Meeting' ]

# %%
pd.to_datetime(meetings, format= '%b %d %Y Meeting')
# Out:
# DatetimeIndex(['2019-12-11', '2020-01-06', '2020-03-19', '2020-04-15'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ### Dates and DataFrames

# %%
ufos = pd.read_csv("DataAnalysis/data/nuforc_reports.csv")
ufos.head(3)
# Out:
#                                              summary        city state  \
# 0  My wife was driving southeast on a fairly popu...     Chester    VA
# 1  I think that I may caught a UFO on the NBC Nig...  Rocky Hill    CT
# 2  I woke up late in the afternoon 3:30-4pm. I we...         NaN   NaN
#
#              date_time   shape     duration  \
# 0  2019-12-12T18:43:00   light    5 seconds
# 1  2019-03-22T18:30:00  circle  3-5 seconds
# 2                  NaN     NaN          NaN
#
#                                                stats  \
# 0  Occurred : 12/12/2019 18:43  (Entered as : 12/...
# 1  Occurred : 3/22/2019 18:30  (Entered as : 03/2...
# 2  Occurred : 4/1/2019 15:45  (Entered as : April...
#
#                                          report_link  \
# 0  http://www.nuforc.org/webreports/151/S151739.html
# 1  http://www.nuforc.org/webreports/145/S145297.html
# 2  http://www.nuforc.org/webreports/145/S145556.html
#
# ...

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  object
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
# dtypes: float64(2), object(10)
# memory usage: 8.1+ MB

# %%
pd.to_datetime(ufos['date_time'])
# Out:
# 0       2019-12-12 18:43:00
# 1       2019-03-22 18:30:00
# 2                       NaT
# 3       2019-04-17 02:00:00
# 4       2009-03-15 18:00:00
#                 ...
# 88120   2019-10-02 20:00:00
# 88121   2019-10-02 20:00:00
# 88122   2019-10-02 20:03:00
# 88123   2019-10-02 22:00:00
# 88124   2019-10-02 22:00:00
# Name: date_time, Length: 88125, dtype: datetime64[ns]

# %%
ufos['date'] = pd.to_datetime(ufos['date_time'])

# %%
ufos.head(3)
# Out:
#                                              summary        city state  \
# 0  My wife was driving southeast on a fairly popu...     Chester    VA
# 1  I think that I may caught a UFO on the NBC Nig...  Rocky Hill    CT
# 2  I woke up late in the afternoon 3:30-4pm. I we...         NaN   NaN
#
#              date_time   shape     duration  \
# 0  2019-12-12T18:43:00   light    5 seconds
# 1  2019-03-22T18:30:00  circle  3-5 seconds
# 2                  NaN     NaN          NaN
#
#                                                stats  \
# 0  Occurred : 12/12/2019 18:43  (Entered as : 12/...
# 1  Occurred : 3/22/2019 18:30  (Entered as : 03/2...
# 2  Occurred : 4/1/2019 15:45  (Entered as : April...
#
#                                          report_link  \
# 0  http://www.nuforc.org/webreports/151/S151739.html
# 1  http://www.nuforc.org/webreports/145/S145297.html
# 2  http://www.nuforc.org/webreports/145/S145556.html
#
# ...

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  object
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
#  12  date            86938 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(10)
# memory usage: 8.7+ MB

# %%
ufos['date_time']=pd.to_datetime(ufos.date_time)

# %%
ufos.drop(columns=['date'],inplace=True)

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(9)
# memory usage: 8.1+ MB

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state           date_time      shape     duration  \
# ...

# %% [markdown]
# ### useful dt properties

# %%
ufos.date_time
# Out:
# 0       2019-12-12 18:43:00
# 1       2019-03-22 18:30:00
# 2                       NaT
# 3       2019-04-17 02:00:00
# 4       2009-03-15 18:00:00
#                 ...
# 88120   2019-10-02 20:00:00
# 88121   2019-10-02 20:00:00
# 88122   2019-10-02 20:03:00
# 88123   2019-10-02 22:00:00
# 88124   2019-10-02 22:00:00
# Name: date_time, Length: 88125, dtype: datetime64[ns]

# %%
ufos.date_time.dt.year
# Out:
# 0        2019.0
# 1        2019.0
# 2           NaN
# 3        2019.0
# 4        2009.0
#           ...
# 88120    2019.0
# 88121    2019.0
# 88122    2019.0
# 88123    2019.0
# 88124    2019.0
# Name: date_time, Length: 88125, dtype: float64

# %%
ufos.date_time.dt.year.value_counts()
# Out:
# 2014.0    8704
# 2012.0    8124
# 2013.0    7823
# 2015.0    6915
# 2019.0    5767
# 2016.0    5664
# 2011.0    5630
# 2008.0    5307
# 2017.0    5057
# 2009.0    4996
# 2010.0    4786
# 2007.0    4736
# 2006.0    3720
# 2018.0    3273
# 2005.0     566
# 2004.0     340
# 1997.0     300
# 2001.0     263
# 2000.0     243
# 2003.0     238
# 1998.0     229
# 2002.0     220
# 1999.0     220
# 1995.0     219
# 1996.0     200
# 1994.0     197
# 1978.0     195
# 1975.0     180
# 1977.0     169
# 1976.0     164
# 1974.0     148
# 1979.0     148
# 1993.0     148
# 1988.0     147
# 1973.0     138
# 1985.0     133
# 1990.0     132
# 1989.0     131
# 1980.0     131
# 1992.0     130
# 1987.0     124
# 1991.0     119
# 1986.0     111
# 1983.0     109
# 1981.0     106
# 1970.0     100
# 1982.0      97
# 1969.0      97
# 1972.0      92
# 1984.0      84
# 1971.0      68
# Name: date_time, dtype: int64

# %%
ufos.date_time.dt.year.value_counts().head(20).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
ufos.date_time.dt.month.sort_values().value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### comparing dates

# %%
(ufos.date_time < '1980').value_counts()
# Out:
# False    86626
# True      1499
# Name: date_time, dtype: int64

# %%
ufos[ufos.date_time < '1980']
# Out:
#                                                  summary  \
# 8      Ufos report in Irving Texas at 2200 hrs. On or...
# 15        Strange bright light hovered over mobile home.
# 31     Bright green round object quickly travelling e...
# 54     It was a full moon when my brother and I obser...
# 55              UFO over Orangevale, CA in May/June 1969
# ...                                                  ...
# 87166  VERY LARGE OBJECT- WHITE LIGHT ILLUMINATING MY...
# 87167  7 "PEARLESCENT" HIGH ALTITUDE CRAFT IN V FORMA...
# 87168  The even occurred North of Mt Calvary Rd on Ol...
# 87169  Triangle ship passed over silent with 7 green ...
# 87170  While trick or treating with Mom, my Grandma p...
#
#                         city state           date_time     shape  \
# 8                     Dallas    TX 1973-07-14 22:00:00      oval
# 15                Gray Court    SC 1975-07-17 00:00:00     light
# 31     N. Cascades Nat. Park    WA 1979-07-15 23:00:00     light
# ...

# %%
ufos['posted'] = pd.to_datetime(ufos.posted)

# %%
ufos[ufos.date_time.dt.hour == 1.0]
# Out:
#                                                  summary              city  \
# 13     I was in pool and my wife was sitting on the e...              Waco
# 17     Star-like light that started bouncing in the a...           Abilene
# 26     Spotted it behind my property next to Rt 476 N...  West Bowmanstown
# 74     Close Encounters of the real kind (space craft...      New Rochelle
# 88     Cigar shaped ufo moving at speed of falling st...      Hillsborough
# ...                                                  ...               ...
# 88055              Green, red and white flashing lights.       Baton Rouge
# 88078  hi my name is Hossein I saw flash lights in on...     kerman , Iran
# 88079  Illuminated satellite like object that turned ...         Dunnellon
# 88096  Shooting star that slows down to an almost com...       Great Falls
# 88112                              Don't care it happend           Hayfork
#
# ...

# %%
ufos[ufos.date_time.dt.hour.between(3,6)]
# Out:
#                                                  summary  \
# 29     ((HOAX))  A fleet of ships landed in my back g...
# 128    Triangle craft with one large softwhite light ...
# 133                              thrilling & terrifying.
# 140    LIndenhurst, Long Island New York -- Triangula...
# 144    It  seemed like minutes passed, but only seconds.
# ...                                                  ...
# 88099  I was sitting on front porch when I suddenly f...
# 88113  ((NUFORC Note:  Witness does not include any d...
# 88114  I was driving to work and I’m the only one on ...
# 88115                             Cigar shapes in Nassau
# 88116  Stepped out into our backyard to let out the d...
#
#                               city state           date_time     shape  \
# 29     Woodford Green (UK/England)   NaN 2006-02-06 04:30:00     other
# 128                       Powhatan    VA 1988-03-08 05:20:00  triangle
# ...

# %%
ufos[ufos.date_time.between('1988','1989')]
# Out:
#                                                  summary  \
# 128    Triangle craft with one large softwhite light ...
# 129    -Working the night shift,and always watching t...
# 130    one shining spiral  moves fast from southwest ...
# 134    Charbonneau Park, Rosemere, PQ. Diamond shaped...
# 750    what are those two 5-6 ft spheres floating on ...
# ...                                                  ...
# 81661  4 days of missing time while working in a remo...
# 82524  Very bright light moving from South to North, ...
# 82652  Beam of light with no sound; no indication of ...
# 84662  I was called to the back porch by my grandmoth...
# 87173  hovering saucer with colored lights flew and s...
#
#                           city state           date_time     shape  \
# 128                   Powhatan    VA 1988-03-08 05:20:00  triangle
# 129                     Woburn    MA 1988-06-20 01:00:00     light
# 130    Suzhou, Jiangsu (China)   NaN 1988-08-10 15:00:00    circle
# ...

# %% [markdown]
# ### date math and time deltas

# %%
ufos['time_before_reporting'] = ufos.posted - ufos.date_time

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   summary                88095 non-null  object
#  1   city                   87891 non-null  object
#  2   state                  82890 non-null  object
#  3   date_time              86938 non-null  datetime64[ns]
#  4   shape                  85627 non-null  object
#  5   duration               84954 non-null  object
#  6   stats                  88088 non-null  object
#  7   report_link            88125 non-null  object
#  8   text                   88070 non-null  object
#  9   posted                 86938 non-null  datetime64[ns]
#  10  city_latitude          72013 non-null  float64
#  11  city_longitude         72013 non-null  float64
#  12  time_before_reporting  86938 non-null  timedelta64[ns]
# ...

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state           date_time      shape     duration  \
# ...

# %%
ufos.time_before_reporting.dt.days.value_counts().head(24).plot(kind='bar')
# Out:
# <AxesSubplot:>
